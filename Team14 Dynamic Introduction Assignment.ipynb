# %% [markdown]
# #    Python for Data Analysts: Methods & Tools - DAT-7466 - FMBAN1

# %% [markdown]
# #                            Team 14 - A3: Dynamic Team Introduction

# %% [markdown]
#  **Dynamic** **Team** **14** **Introduction**
#
# Glad you are curious about Team 14 😊 Let's get started !
#
# Our team has 5 members :
#
# *   Sreekar Bathula
# *   Olubiyi George
# *   Deena Jivan
# *   Akoh Jackson Udeng
# *   Zaynab Zennour
#
# *Sreekar Bathula* is 24 and is from India. Our teammate likes traveling,
# vacation planning, interior designing and gardening.
# He graduated in Mechanical Engineering and worked in IT industry for 3 years.
#
# *Olubiyi George* is 36 and is from Nigeria. Our teammate likes gaming, movies, traveling athletics. He has a B.Sc in Business Administration and worked in Human Resources for 10 years.
#
# *Deena Jivan* is 44 and is from South Africa. Our teammate likes gardening, gaming, coocking, sports, action movies and spending time with family and friends. This team member has a bachelor degree in Commerce and a mojor in Financial Management, worked in Accounting for more than 20 years.
#
# *Akoh Jackson Udeng* is 31 and is from Cameroon. Our teammate likes football, traveling and watching movies. This team member has a degree in Geosciences.
#
# *Zaynab Zennour* is 27 and is from Morocco. Our teammate likes traveling, hiking, sports and watching documentaries. This team member has a master in industiral engineering and operations research, worked in Supply Chain industry for 4 years.

# %% [markdown]
# ![Team14.jpg](attachment:Team14.jpg)

# %%
## importing sleep from time package in python
from time import sleep
warm_emoji = "\U0001F60A"
winking_emoji = "\U0001f609"
grinding_emoji ="\U0001f600"
## team details in list.
team = [
    ["Sreekar Bathula","24","India","Traveling, Vacation Planning, Interior Designing and Gardening", "Graduated in Mechanical Engineering and worked in IT industry for 3 years"],
    ["Olubiyi George"	,"36"	,"Nigeria",	"Gaming, Movies, Traveling, Athletics"	, "B.Sc in Business Administration and worked in Human Resources for 10 years"],
    ["Deena Jivan","44","South Africa",	"Gardening, Gaming, Cooking, Sports, Action Movies and Spending time with family and friends",	"Bachelor Degree in Commerce and a Major in Financial Management, Worked in Accounting for  20 years"],
    ["Akoh Jackson Udeng"	,	"31",	"Cameroon" ,	"football, traveling and watching movies", "Degree in Geosciences" ],
    ["Zaynab Zennour"	,"27"	,"Morocco",	"Traveling, Hiking, Sports and Watching Documentaries",	"Masters in Industrial Engineering and Operations Research, Worked in Supply Chain Industry for 4 years" ]
]
## format to be displayed for each team member
msg = "\n\nName       : {}.\nAge        : {}.\ncountry    : {}.\nHobbies    : {}.\nBackground : {}.\n__________________________________________________________________"
one_msg = "\n__________________________________________________________________\nName       : {}.\nAge        : {}.\ncountry    : {}.\nHobbies    : {}.\nBackground : {}.\n__________________________________________________________________"
reapeatedMsg = msg*5

## greeting the user, requesting the user name
print(f'Hii Friend!\nHope you are smiling today...',warm_emoji,winking_emoji,grinding_emoji)

#making the screen sleep for2 seconds
sleep(2)
print(f'I am glad to introduce my creators.\n')
sleep(2)
user = input(f'Please enter your name...\n')
user=user.title()

## introducing the list of team members and requesting the user to choose if they want to proceed getting to know the team
list_input = ['1','2','3','4','5']
sleep(1)
print(f'\n\n ----------**----------\nWelcome {user}!',grinding_emoji,grinding_emoji) 
sleep(1)
print("""\n 
  _______  _      _        _        _______                        __  _  _     _  
 |__   __|| |    (_)      (_)      |__   __|                      /_ || || |   | | 
    | |   | |__   _  ___   _  ___     | |  ___   __ _  _ __ ___    | || || |_  | | 
    | |   | '_ \ | |/ __| | |/ __|    | | / _ \ / _` || '_ ` _ \   | ||__   _| | | 
    | |   | | | || |\__ \ | |\__ \    | ||  __/| (_| || | | | | |  | |   | |   |_| 
    |_|   |_| |_||_||___/ |_||___/    |_| \___| \__,_||_| |_| |_|  |_|   |_|   (_) 
                                                                                   
                                                                                   \n """)
sleep(1)
print('Happy to introduce my Creators!\n')
sleep(1)
next = input('If Yes, type Y, if not type N: \t')
next = next.casefold()
sleep(1)

## conditions for the user to proceed further and select the options
if next == 'y' :
    print(f'__________________________________________________________________')
    sleep(1)
    print('\nLet\'s get started !') 
    sleep(1)
    print('I will make it easier for you.\n')
    sleep(2)
    print(f'__________________________________________________________________')
    print('Select 1 to 5, you have 5 attempts\n') 
    print('Select 0 you have only 1 attempt')
    print('\nNote: option  0 available only at beginning\n')
    print(f'*******************************************************************')
    print('\nInvalid entry will make you lose')
    print(f'*******************************************************************')
    sleep(2)
    number = input( "\n\nLook into options\n--------------------\n1)Sreekar Bathula\n2)Olubiyi George\n3)Deena Jivan\n4)Akoh Jackson Udeng\n5)Zaynab Zennour\n0)All details\n\n")
    sleep(1)

## Condition for the option 0, where it displays all the details of the team.    
    if number == '0' : 
        sleep(1)
        print("\nCool ! Glad you are curious to know about all the team \n -------------------------------------------------------------\n")
        sleep(1)
        print(warm_emoji,"Alright, let\'s begin !\n\n")
        sleep(2)
        print(reapeatedMsg.format(*team[0], *team[1], *team[2], *team[3], *team[4]))
        sleep(2)
        print(f'\n\nThank you {user}!\n\n')
        sleep(0.5)
        print(grinding_emoji,grinding_emoji,grinding_emoji,grinding_emoji,grinding_emoji)
        print("Re-run me to choose more options")
        
## Giving the user to select the option and displaying the desired output.  
    elif number in list_input :
        sleep(1)
        print(one_msg.format(*team[int(number)-1]))
        sleep(1)
        list_input.remove(number)
## displaying user the attempts left.   
        second = input ("1/5 attempts are done you have 4 more attempts to go \n\n1)Sreekar Bathula\n2)Olubiyi George\n3)Deena Jivan\n4)Akoh Jackson Udeng\n5)Zaynab Zennour\n\nYou have already chosen team member number {}\nIf you press another key, you will lose an attempt\n".format(number))
        sleep(1)
## conditional statement, if a user chooses an invalid selection, no details of a team member will be displayed and user will loose an attempt    
        if second in list_input :
            print (one_msg.format(*team[int(second)-1]))
            list_input.remove(second)
        
        else : 
            sleep(1)
            print( "Invalid entry, you lost an attempt!")
            sleep(1)
## user has another attempt to meet a team member        
        third = input ("2/5 attempts are done you have 3 more attempts to go \n\n1)Sreekar Bathula\n2)Olubiyi George\n3)Deena Jivan\n4)Akoh Jackson Udeng\n5)Zaynab Zennour\n\nYou have already chosen team member number {} and number {} \nIf you press another key, you will lose an attempt\n ".format(number, second))
        sleep(1)
## user chooses a number from the team member list, invalid choices will display and error and an attempt will be lost    
        if third in list_input :
            print (one_msg.format(*team[int(third)-1]))
            list_input.remove(third)
              
        else : 
            print( "Invalid entry, you lost an attempt!")
            sleep(1)
## attempt number 4 for the user, this is the second last choice the user will have to meet the user    
        fourth= input ("3/5 attempts are done you have 2 more attempts to go \n\n1)Sreekar Bathula\n2)Olubiyi George\n3)Deena Jivan\n4)Akoh Jackson Udeng\n5)Zaynab Zennour\n\nYou have already chosen team member number {}, number {} and number {}\nIf you press another key, you will lose an attempt\n".format(number, second, third))
        sleep(1)
    
        if fourth in list_input :
            print (one_msg.format(*team[int(fourth)-1]))
            list_input.remove(fourth)
        
        
## is the choice valid, if so, the team members details will be shown, if not the user will loose an attempt    
        else : 
            print( "Invalid entry, you lost an attempt! ")
        fifth = input ("4/5 attempts are done you have 1 more attempts to go \n\n1)Sreekar Bathula\n2)Olubiyi George\n3)Deena Jivan\n4)Akoh Jackson Udeng\n5)Zaynab Zennour\n\nYou have already chosen team member number {}, number {}, number {} and number {}\nIf you press another key, you will lose an attempt\n".format(number, second, third, fourth))
        sleep(1)
## displaying the results of the final attempt     
        if fifth in list_input :
            print (one_msg.format(*team[int(fifth)-1]))
            sleep(1)
        
 ## thanking the user, and hoping they had fun       
        else : 
            print( "Invalid entry, you lost an attempt!")
        print("\n\nHope you had fun with our team"+warm_emoji)
        print(""" 
  _______  _                    _                            _ 
 |__   __|| |                  | |                          | |
    | |   | |__    __ _  _ __  | | __  _   _   ___   _   _  | |
    | |   | '_ \  / _` || '_ \ | |/ / | | | | / _ \ | | | | | |
    | |   | | | || (_| || | | ||   <  | |_| || (_) || |_| | |_|
    |_|   |_| |_| \__,_||_| |_||_|\_\  \__, | \___/  \__,_| (_)
                                        __/ |                  
                                       |___/                   
""")
        sleep(1)
## letiing the user know he can try again        
    else : 
        print('Invalid Entry'.format(warm_emoji))
        print('You lost')
        sleep(1)
        print('Re-run to meet my people')


elif next == 'n' : 
  print('You can try next time, see you soon !{}'.format(warm_emoji))
  print(""" 
  _______  _                    _                            _ 
 |__   __|| |                  | |                          | |
    | |   | |__    __ _  _ __  | | __  _   _   ___   _   _  | |
    | |   | '_ \  / _` || '_ \ | |/ / | | | | / _ \ | | | | | |
    | |   | | | || (_| || | | ||   <  | |_| || (_) || |_| | |_|
    |_|   |_| |_| \__,_||_| |_||_|\_\  \__, | \___/  \__,_| (_)
                                        __/ |                  
                                       |___/                   
""")
else :
  print('Y or N only : Try Y, to get to know Team 14, type N to exit !{}'.format(warm_emoji))
print("""
   _____                                                                _ 
  / ____|                                                              | |
 | (___    ___   ___   _   _   ___   _   _   ___   ___    ___   _ __   | |
  \___ \  / _ \ / _ \ | | | | / _ \ | | | | / __| / _ \  / _ \ | '_ \  | |
  ____) ||  __/|  __/ | |_| || (_) || |_| | \__ \| (_) || (_) || | | | |_|
 |_____/  \___| \___|  \__, | \___/  \__,_| |___/ \___/  \___/ |_| |_| (_)
                        __/ |                                             
                       |___/                                              
""")
# Out:
# Hii Friend!
# Hope you are smiling today... 😊 😉 😀
# I am glad to introduce my creators.
#
# Please enter your name...
# R
#
#
#  ----------**----------
# Welcome R! 😀 😀
#
#
#   _______  _      _        _        _______                        __  _  _     _
#  |__   __|| |    (_)      (_)      |__   __|                      /_ || || |   | |
#     | |   | |__   _  ___   _  ___     | |  ___   __ _  _ __ ___    | || || |_  | |
#     | |   | '_ \ | |/ __| | |/ __|    | | / _ \ / _` || '_ ` _ \   | ||__   _| | |
#     | |   | | | || |\__ \ | |\__ \    | ||  __/| (_| || | | | | |  | |   | |   |_|
#     |_|   |_| |_||_||___/ |_||___/    |_| \___| \__,_||_| |_| |_|  |_|   |_|   (_)
#
#
#
# Happy to introduce my Creators!
#
# If Yes, type Y, if not type N: 	Y
# __________________________________________________________________
#
# Let's get started !
# I will make it easier for you.
#
# __________________________________________________________________
# Select 1 to 5, you have 5 attempts
#
# ...
