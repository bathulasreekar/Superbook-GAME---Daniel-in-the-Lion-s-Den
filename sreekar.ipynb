# %% [markdown]
# <table align="left" width=100%>
#             <div align="center">
#                 <font color="#21618C" size=16px>
#                   <b> Text Adventure Game </b>
#                 </font>
#     </div>
# </table>
#
#
#
# <table align="left" width=100%>
#             <div align="center">
#                 <font color="#21618B" size=6px>
#                   <b> Python for Data Analysts </b>
#                 </font>
#     </div>
# </table>
#
#
#
#
# <table align="right">
#     <tr>
#         <td width="15%">
#         </td>
#         <td>
#             <div align="left", style="font-size:120%">
#                 <font color="#21618C">
#                     <b><br>
#                         Name       : Sreekar Bathula<br>
#                         Student id : 28067764<br>
#                         Course     : Master's in Business Analytics<br>
#                         School     : Hult International Business School
#                     </b>
#                 </font>
#             </div>
#         </td>
#     </tr>
# </table>
#
#
#
# <table align="center" width=100%>
#             <div align="center">
#                 <font color="#21618B" size=6px>
# <b> ___________________________________________________________________________________________________________ </b>
#                 </font>
#     </div>
# </table>
#
#
# <table align="left" width=100%>
#             <div align="center">
#                 <font color="#21618B" size=26px>
#                     <b> Super Book </u>
#                 </font>
#     </div>
# </table>
#
# <table align="left" width=100%>
#             <div align="center">
#                 <font color="#21618B" size=6px>
#                   <b> Roar - Daniel and the Lion's Den </b>
#                 </font>
#     </div>
# </table>

# %% [markdown]
# ![sb.png](attachment:sb.png)

# %% [markdown]
# <table align="center" width=100%>
#             <div align="center">
#                 <font color="#21618B" size=6px>
# <b> ___________________________________________________________________________________________________________ </b>
#                 </font>
#     </div>
# </table>

# %% [markdown]
# **Superbook - Daniel in the Lion's Den**
#
#
# **Superbook. (2020). "Daniel in the Lions' Den." [Television series episode]. In Superbook. Produced by CBN.**
#
# **Description** **:**
# Superbook is an animated Christian television series that tells children the stories of the Bible. In the episode "Daniel of the Lion's Den", the characters travel back in time to meet the Prophet Daniel in ancient Babylon. Daniel is wrongly accused by his jealous rivals and thrown into a lion's den as punishment. Faith in God protects and ultimately saves him. This story teaches children the power of faith and the importance of standing up for what is right in the face of danger. It also shows that God's protection is always with us even in difficult situations. Overall, the series is designed to teach children about the Bible and its teachings through engaging stories and characters.
#
# **Game Objectives** **:**
# The goal of my text adventure game is to teach protagonist Chris the importance of standing up for what is right. Using the story "Daniel in the Lion's Den" as a basis, players will guide Chris through various levels and challenges, helping him understand the value of courage and faith. Players will explore Daniel's story and the protective power of God while helping Chris make the right choices. The game aims to inspire players to be brave and trust in God even in difficult situations. Through interactive gameplay and biblical teachings, players will learn valuable lessons in a fun and engaging way.

# %% [markdown]
# <table align="center" width=100%>
#             <div align="center">
#                 <font color="#21618B" size=6px>
# <b> ___________________________________________________________________________________________________________ </b>
#                 </font>
#     </div>
# </table>

# %%
#Introduction of game
from time import sleep

# Function defining characters.
def characters():
    # creating variables to store emoji's.
    C = u"\U0001F466\U0001F3FB"#Emoji for chris
    J=u"\U0001F467\U0001F3FB"#Emoji for Joy
    G=u"\U0001F916"#Emoji for Gizmo
    K=u"\U0001F934\U0001F3FC"#Emoji for king
    M=u"\U0001F474\U0001F3FB"#Emoji for Man
    T=u"\U0001F476\U0001F3FB"#Emoji for Tommy
    B=u"\U0001F468\U0001F3FC\u200D\U0001F9B1"#Emoji for Barry
    A=u"\U0001F9DB\u200D\u2642\uFE0F"#Emoji for Arnasal
    D=u"\U0001F473\U0001F3FB"#Emoji for Daniel
    SB=u"\U0001F4D5"#Emoji for Super book
    C2=u"\U0001F482\U0001F3FE"#Emoji for conspirator
    HE=u"\U0001F60D"#Emoji of love
    SF=u"\uE414"#emoji for smiling face
    party=u"\U0001F973"#Emoji for celebrations
    exc=u"\u2668\uFE0F"#emoji for starting
    #Taking input from user to display his name.
    user = input(prompt=f'Hii friend.....'+HE+HE+'\nPlease enter your name to get started...\n')
    user=user.title()
    print(f'\nWelcome {user}!'+party+' In this game you are going to help Chris to fight his gaints.\n')
    print("Before moving forward, Let me intoduce you the characters.\n")
    #input prompt to continue
    input(prompt= f"{user}! Enter any key to move Forward")
    #Introducing Characters to user
    print("\n\n"+exc+"    -----Characters Introduction-----    "+exc)
    #storing the characters in list
    characters=[["      Chris",C, "The main lead - who lacks strenght so, you are going to help him."],
            ["        Joy",J,"She is Chris's Sister - She will help Chris everywhere"],
            ["      Gizmo",G,"He is a robot and best friend to Chris and Joy"],
            ["  Superbook",SB,"Superbook will help Chris to fight his weakness by telling him stories through time travel"],
            ["      Tommy",T,"Poor little boy seeking for help"],
            ["      Barry",B,"Rough street boy"],
            ["     Daniel",D,"Hero of the story, helps Chris to learn fight his weakness"],
            ["King Darius",K,"Friend of Daniel"],
            ["    Arsalan",A,"Enemy to daniel and making trap to kill Daniel"],
            ["        Man",M,"Tell Chris the way to Daniel's House"],
            ["Conspirator",C2,"Friend of Arsalan - Helps Arsalan to make traps"]
           ]
    print("___________________________________________________________________________________________________________________")
    #Loop to display characters one by one
    for names,code,msg in characters:
        print(names+code+" : "+ msg)
        sleep(0.5)
    print("___________________________________________________________________________________________________________________")
      #prompting to continue to skate_board_ground user displayed function.  
    skate_board_ground()
        
    



#user defined function to skate_board_ground
def skate_board_ground():
    
    C = u"\U0001F466\U0001F3FB"#Emoji for Chris
    J=u"\U0001F467\U0001F3FB"#Emoji for Joy
    G=u"\U0001F916"#Emoji for Gizmo
    K=u"\U0001F934\U0001F3FC"#Emoji for King
    M=u"\U0001F474\U0001F3FB"#Emoji for man
    T=u"\U0001F476\U0001F3FB"#EMoji for Tommy
    B=u"\U0001F468\U0001F3FC\u200D\U0001F9B1"#emoji for Barry
    A=u"\U0001F9DB\u200D\u2642\uFE0F"#Emoji for Arsalan
    D=u"\U0001F473\U0001F3FB"#Emoji for Daniel
    SB=u"\U0001F4D5"#Emoji for Superbook
    C1="\xee\x94\x9e"#Emoji for conspirator1
    C2=u"\U0001F482\U0001F3FE"#Emoji for conspirator2
    HE=u"\U0001F60D"#Emoji for love face
    SF=u"\uE414" #Emoji for smiling face
    SG=u"\U0001F576"#EMoji to smile
    skateboard=u"\U0001F3C2"#emoji for skateboard
    sboard=	u"\U0001F6F9"#emoji for skatebaord
    hahaha=	u"\U0001F602"#Emoji for laughing
    sad=u"\U0001F61E"#Emoji for sad
    party=u"\U0001F973"#Emoji for celebrations
    exc=u"\u2668\uFE0F"#EMoji to to note.
    #prompting the user to continue forward
    next = input(prompt= f"You look so excited!!..."+HE+HE+"\nWant to begin the game?\nIf Yes, press y,else press n:\t")
    #casefolding the user input
    next = next.casefold()
    loop1=0
    #using whle loop to continue in the loop
    while loop1==0:
        #using the conditional statement if the user select y
        if next == 'y':
            #increasing the value of intializing.
            loop1 += 1
            #printing the required outputs
            print("\nLet us get started! " +SG+"\nYou are in level 0.\nGood luck...."+HE+"\n")
            print("|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||\n")
            sleep(0.5)
            print(exc+"   Chris"+C+" just came back from skate"+skateboard+ "and met Joy"+J+" and Gizmo"+G+"   "+exc)
            print("___________________________________________________________________________________________________________________")
            sleep(0.5)
            print("  Joy" +J+" : Totally awesome Chris")
            sleep(0.5)
            print("Chris" +C+" : Oh,Yeah Thank you Joy")
            #using the sleep function to delay the response and make it user interactive.
            sleep(0.5)
            print("Gizmo" +G+" : You are best in Skating Chris")
            sleep(0.5)
            print("Chris" +C+" : Yoooo\n\n")
            sleep(0.5)
            print(exc+"   Beside Barry"+B+" a street boy making little poor boy Tommy"+T+" cry by steeling his skate board"+sboard+"   "+exc)
            print("___________________________________________________________________________________________________________________")
            sleep(0.5)
            print("Tommy" +T+" : Hey Gimme, Baryy!!  That's mine")
            sleep(0.5)
            print("Barry" +B+" : Hahaha"+hahaha+"! come on, come on, come on. Take it from me\n\n")
            sleep(0.5)
            print(exc+"   Everyone there are wondering unable to help poor little Tommy. "+sad+ sad+"   "+exc)
            print("___________________________________________________________________________________________________________________")
            sleep(0.5)
            print("  Joy" +J+"   : Chris You gotta do something")
            sleep(0.5)
            print("Chris" +C+"   : Me?! I dont even know them")
            sleep(0.5)
            print("  Joy" +J+"   : what's the matter. You gotta stand up when someone smaller's in trouble")
            sleep(0.5)
            print("Chris" +C+"   : why? I dont have enough strenght")
            sleep(0.5)
            print("  Joy" +J+"   : Come On, It's right to do")
            sleep(0.5)
            print("Barry" +B+" : Hey Tommy! Cry baby Cry. It's yours. If you can take it.")
            sleep(0.5)
            print("  Joy" +J+" : Chris do something.")
            sleep(0.5)
            print("Chris" +C+" : Uhh! Let's Go home other way.")
            sleep(0.5)
            print("  Joy" +J+" : Chris...............")
            loop2=0
            
            #using the loop for which displaying options to the users and continueing the loop.
            while loop2 == 0:
                gaint1 = input(prompt = f"Do you want to help Chris to get his strenght?\n\nSuperBook wants you Chris, Joy and Gizmo timetravel to meet someone\nTo Help press y,want to exit press n")
                gaint1 = gaint1.casefold()
                #using conditional statatements as per the user selection.
                if gaint1 == 'y':
                    loop2 += 1
                    #diverting to babylon if user input is y
                    babylon()
                    break
                    
                #If user option is y, then excuting this  
                elif gaint1 == 'n':
                    #diverting to exit if the user selection is y
                    fail()
                    exit()
                    break
                    
                #conditional statement if the option is not in the options    
                else :
                    print('Invalid entry\n')
                    gaint1 = input(f"!Do you want to help Chris to fight his Gaint?\nSuperBook wants you to timetravel to meet someone\nIf yes press y,want to exit press n")
                    gaint1 = gaint1.casefold()
                    continue
            break
        #other conditional statement if the option is y                           
        elif next=='n':
            exit()#prompting to exit
            break

         #prompting to continue in the loop   
        else:
            print('Invalid entry\n')
            next = input(prompt = f"Want to begin the game?\nIf Yes, press y,else press n:\t")
            next = next.casefold()
            continue
                    
    

    
    
#Kings palace - Level 1

def babylon():
    C = u"\U0001F466\U0001F3FB"#emoji
    J=u"\U0001F467\U0001F3FB"#emoji
    G=u"\U0001F916"#emoji
    K=u"\U0001F934\U0001F3FC"#emoji
    M=u"\U0001F474\U0001F3FB"#emoji
    T=u"\U0001F476\U0001F3FB"#emoji
    B=u"\U0001F468\U0001F3FC\u200D\U0001F9B1"#emoji
    A=u"\U0001F9DB\u200D\u2642\uFE0F"#emoji
    D=u"\U0001F473\U0001F3FB"#emoji
    SB=u"\U0001F4D5"#emoji
    C1="\xee\x94\x9e"#emoji
    C2=u"\U0001F482\U0001F3FE"#emoji
    HE=u"\U0001F60D"#emoji
    SF=u"\uE414"#emoji
    SG=u"\U0001F576"#emoji
    skateboard=u"\U0001F3C2"#emoji
    sboard=	u"\U0001F6F9"#emoji
    hahaha=	u"\U0001F602"#emoji
    sad=u"\U0001F61E"#emoji
    party=u"\U0001F973"#emoji
    threepeople=u"\U0001F468\u200D\U0001F468\u200D\U0001F466"#emoji
    trumpet=u"\U0001F3BA"#emoji
    pray=u"\U0001F647\u200D\u2640\uFE0F"#emoji
    exc=u"\u2668\uFE0F"#emoji
    
    #printing the required statements
    print("Congratulations!"+party+"You are into Level 1.\n\n")
    print("|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||\n")
    sleep(0.5)
    print('___________________________________________________________________________________________________________________')
    print("   "+exc+"Superbook"+SB+" is Making Chris"+C+", Joy"+J+" and Gizmo"+G+" time travel to B.C"+"  "+exc+"\n")
    sleep(0.5)
    print("SuperBook" +SB+": I am taking you to meet a man who stood for what he belived was right, Even though it was the most dangerous choice.")
    print('___________________________________________________________________________________________________________________\n\n')
    sleep(0.5)
    print(' Chris' +C+' : Giz!!Where are we?')
    sleep(0.5)
    print(' Gizmo' +G+' : It appears we are in Ancient Babylon approximately 500 B.C.')
    sleep(0.5)
    print('   Joy' +J+' : Listen! Listen - Someone is over there.')
    sleep(0.5)
    print('  King' +K+' : Daniel!My friend, You have found great favour with my court.You are wise above all the men in my kingdom and I thank you for all you have done')
    sleep(0.5)
    print('Daniel' +D+' : I am humbled my lord. But, my wisdom only comes from the God Almighty who can who continually gives me strenght as I pray')
    sleep(0.5)
    print('  King' +K+' : You speak so much about your God')
    sleep(0.5)
    print('Daniel' +D+' : All that I am, All that I have - Is only because of him')
    sleep(0.5)
    print('  King' +K+' : Ah Daniel! if only I could believe in anything as much you believe in your God.')
    sleep(0.5)
    print('\n')
    print("Chris" +C+"  : Now its our chance to sneak out\n")
    sleep(0.5)
    #intiatizing the value to continue in the loop
    sk=0
    #using while loop to compiler continue in the same loop untill it fails.
    while sk==0:
        sneak=input(prompt = f'Someone is trying to trap innocent Daniel..\nYou want to listen to their conversation and help Daniel or you want to escape from that place?\nTo Listen : press 1\nEscape : press 0.\n')
        #using try and except to handle the input
        try:
            sneak = int(sneak)
            
        except:
            input(prompt = "I need a number in digits. Press enter to try again.\n")
            continue
         #conditional statement for the options displayed   
        if sneak == 1:
            #prompting user to continue to the user defined function
            listen_con()
            break
            
        elif sneak == 0:
            #diverting  the compiler to other condition
            print("You choose to escape - You lost")
            fail()
            exit()
            break
                
        else:
            #else statement if the option didnt present
            print("Enter the valid input\n\n")
            continue
    
    
   # user defined function -listen_con
def listen_con():
    C = u"\U0001F466\U0001F3FB"#emoji
    J=u"\U0001F467\U0001F3FB"#emoji
    G=u"\U0001F916"#emoji
    K=u"\U0001F934\U0001F3FC"#emoji
    M=u"\U0001F474\U0001F3FB"#emoji
    T=u"\U0001F476\U0001F3FB"#emoji
    B=u"\U0001F468\U0001F3FC\u200D\U0001F9B1"#emoji
    A=u"\U0001F9DB\u200D\u2642\uFE0F"#emoji
    D=u"\U0001F473\U0001F3FB"#emoji
    SB=u"\U0001F4D5"#emoji
    C1="\xee\x94\x9e"#emoji
    C2=u"\U0001F482\U0001F3FE"#emoji
    HE=u"\U0001F60D"#emoji
    SF=u"\uE414"#emoji
    SG=u"\U0001F576"#emoji
    skateboard=u"\U0001F3C2"#emoji
    sboard=	u"\U0001F6F9"#emoji
    hahaha=	u"\U0001F602"#emoji
    sad=u"\U0001F61E"#emoji
    party=u"\U0001F973"#emoji
    threepeople=u"\U0001F468\u200D\U0001F468\u200D\U0001F466"#emoji
    trumpet=u"\U0001F3BA"#emoji
    pray=u"\U0001F647\u200D\u2640\uFE0F"#emoji
    exc=u"\u2668\uFE0F"#emoji
    #Higher official coversation
    print('___________________________________________________________________________________________________________________\n\n')
    print(exc+'   Three higher officials'+threepeople+' discussing plot against Daniel   '+exc)
    print('___________________________________________________________________________________________________________________\n\n')
    sleep(0.5)
    print('conspirator1' +C2+' : Arsalan, We have to find something to sort the king favours Daniel.')
    sleep(0.5)
    print("conspirator2" +C2+" : We have tried to find the fault in daniel's work. But there is none.")
    sleep(0.5)
    print('     Arsalan'  +A+' : I have taken care of that matter. Daniel faith will be damn worse.')
    sleep(0.5)
    print('     Arsalan'  +A+' :  For I have convinced the King to sign this Proclaimination')
    sleep(0.5)
    print('     Arsalan'  +A+' : Daniel thinks that he is pious, praying all the time. This is very habit. that is going to be his Demise')
    print('___________________________________________________________________________________________________________________\n\n')
    sleep(0.5)
    print("Chris" +C+" : Those guys are out to get the king's friend")
    sleep(0.5)
    print("  Joy" +J+" : Giz, Chris! we should warn, we need to do something Chris")
    sleep(0.5)
    print("Chris" +C+" : Did you see that guard, they will throw us to lion")
    sleep(0.5)
    print("  Giz" +G+" : we should atleast inform King or Daniel about this trick")
    print('___________________________________________________________________________________________________________________\n\n')
    #intiatizing the value to continue in the loop
    loop3=0
    #loop to display the options to user
    while loop3==0:
        gaint1 = input(prompt = f"Do you want help them about the plot?\nTo tell Daniel: press 1\n To tell King : Press 0")
        #using the try and expect for input handling
        try:
            gaint1 = int(gaint1)
        
        except:
            input(prompt = "I need a number in digits. Press enter to try again.\n")
            continue
            
        #using conditional statements 
        if gaint1 == 1:
            loop3 += 1
            print('___________________________________________________________________________________________________________________\n\n')
            print('Joy' +J+' : Sir, Do you know where will Daniel Live?')
            sleep(0.5)
            print("Man" +M+" : Oh! you are here for Daniel. He is a great man. He prays 3 times a day")
            sleep(0.5)
            print("Giz" +G+" : Where do we find him?")
            sleep(0.5)
            print("Man" +M+" : Last house on that street")
            sleep(0.5)
            print('___________________________________________________________________________________________________________________\n\n')
            print(trumpet+ trumpet+ "!!!!Trumpets Sound!!!!" +trumpet+trumpet)
            print(exc+"   Citizens of Babylon!   "+exc+"\nA Decree from King darius! \nAnyone who prays to any God or man during the next 30 days except the King, You will be thrown into Lion's Den\n So It has been Decreed this day")
            print('___________________________________________________________________________________________________________________\n\n')
            sleep(0.5)
            print("Joy" +J+": Oh no comeon!!")
            sleep(0.5)
            #diverting to funtion daniel house.
            daniel_house()
            break
            
        #if the option is 0, the execute this.
        elif gaint1 == 0:
            print("you choose to tell king - But soldiers caught you as trespassers are prosecuted\nYou lost.")
            fail()
            exit()
            break
          
        #if the options is not present in the options.
        else:
            print('Enter valid Output\n')
            continue
     
    
def tell_daniel(): #user defined function to tell daniel.
    C = u"\U0001F466\U0001F3FB"#emoji's
    J=u"\U0001F467\U0001F3FB"#emoji's
    G=u"\U0001F916"#emoji's
    K=u"\U0001F934\U0001F3FC"#emoji's#emoji's
    M=u"\U0001F474\U0001F3FB"#emoji's
    T=u"\U0001F476\U0001F3FB"#emoji's
    B=u"\U0001F468\U0001F3FC\u200D\U0001F9B1"#emoji's
    A=u"\U0001F9DB\u200D\u2642\uFE0F"#emoji's
    D=u"\U0001F473\U0001F3FB"#emoji's
    SB=u"\U0001F4D5"#emoji's
    C1="\xee\x94\x9e"#emoji's
    C2=u"\U0001F482\U0001F3FE"#emoji's
    HE=u"\U0001F60D"#emoji's
    SF=u"\uE414"#emoji's
    SG=u"\U0001F576"#emoji's
    skateboard=u"\U0001F3C2"#emoji's
    sboard=	u"\U0001F6F9"#emoji's
    hahaha=	u"\U0001F602"#emoji's
    sad=u"\U0001F61E"#emoji's
    party=u"\U0001F973"#emoji's
    threepeople=u"\U0001F468\u200D\U0001F468\u200D\U0001F466"#emoji's
    trumpet=u"\U0001F3BA"#emoji's
    pray=u"\U0001F647\u200D\u2640\uFE0F"#emoji's
    exc=u"\u2668\uFE0F"#emoji's
    
    print('___________________________________________________________________________________________________________________\n\n')
    print('Joy' +J+' : Sir, Do you know where will Daniel Live?')
    sleep(0.5)
    print("Man" +M+" : Oh! you are here for Daniel. He is a great man. He prays 3 times a day")
    sleep(0.5)
    print("Giz" +G+" : Where do we find him?")
    sleep(0.5)
    print("Man" +M+" : Last house on that street")
    sleep(0.5)
    print('___________________________________________________________________________________________________________________\n\n')
    print(trumpet+ trumpet+ "!!!!Trumpets Sound!!!!" +trumpet+trumpet)
    print("Citizens of Babylon!\nA Decree from King darius! \nAnyone who prays to any God or man during the next 30 days except the King, You will be thrown into Lion's Den\nSo It has been Decreed this day")
    print('___________________________________________________________________________________________________________________\n\n')
    sleep(0.5)
    print("Joy" +J+": Oh no comeon!!")
    sleep(0.5)
    daniel_house()
            
    
# Daniel's House - level 3    
    
def daniel_house():
    C = u"\U0001F466\U0001F3FB"#emoji's
    J=u"\U0001F467\U0001F3FB"#emoji's
    G=u"\U0001F916"#emoji's
    K=u"\U0001F934\U0001F3FC"#emoji's
    M=u"\U0001F474\U0001F3FB"#emoji's
    T=u"\U0001F476\U0001F3FB"#emoji's
    B=u"\U0001F468\U0001F3FC\u200D\U0001F9B1"#emoji's
    A=u"\U0001F9DB\u200D\u2642\uFE0F"#emoji's
    D=u"\U0001F473\U0001F3FB"#emoji's
    SB=u"\U0001F4D5"#emoji's
    C1="\xee\x94\x9e"#emoji's
    C2=u"\U0001F482\U0001F3FE"#emoji's
    HE=u"\U0001F60D"#emoji's
    SF=u"\uE414"#emoji's
    SG=u"\U0001F576"#emoji's
    skateboard=u"\U0001F3C2"#emoji's
    sboard=	u"\U0001F6F9"#emoji's
    hahaha=	u"\U0001F602"#emoji's
    sad=u"\U0001F61E"#emoji's
    party=u"\U0001F973"#emoji's
    threepeople=u"\U0001F468\u200D\U0001F468\u200D\U0001F466"#emoji's
    trumpet=u"\U0001F3BA"#emoji's
    pray=u"\U0001F647\u200D\u2640\uFE0F"#emoji's
    exc=u"\u2668\uFE0F"#emoji's
    
    #printing the require statements.
    print("Congratulations!"+party+"You are into Level 2.\nYou have reached Daniel's House\n")
    print("|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||\n")
    
    print(exc+'   Daniel! In his room Praying...........Doors Knocking'+pray+pray+pray)
    print('___________________________________________________________________________________________________________________\n\n')
    sleep(0.5)
    print("   Joy" +J+" : Daniel! You have to Listen to us. we are friends and your in a great Danger")
    sleep(0.5)
    print(" Chris" +C+" : There is a plot to kill you.")
    sleep(0.5)
    print("   Joy" +J+" : King has a decree that anyone who pray except to him will be thrown into Lion's den")
    sleep(0.5)
    print("Daniel" +D+" : Yes! I have known about this proclamination before leaving here. It is not the king doing but the arsanal and his friends")
    sleep(0.5)
    print("   Joy" +J+" : What are you going to do?")
    sleep(0.5)
    print("Daniel" +D+" : What I have been doing...")
    sleep(0.5)
    print("Daniel started praying")
    sleep(0.5)
    print(" Chris" +C+" : You should do it in secret")
    sleep(0.5)
    print("Daniel" +D+" : If I am afraid of what others will say to do, when I do what is right then I have no strenght at all\n\n")
    sleep(0.5)
    print("Daniel opens the window and started praying")
    sleep(0.5)
    print("   Joy" +J+" : I wish I have your strenght")
    sleep(0.5)
    print("Daniel" +D+" : Kneel with me I will teach you how to pray. God wants to tell you what is truly on your heart,Joy. He loves you and wants you to be honest with him even in times of trouble")
    sleep(0.5)
    print('___________________________________________________________________________________________________________________\n\n')
    print(exc+"   Doors knocking!! \n Giz"+G+": I know its them.\n Chris drags joy and hides her.\n Arsanal broke the door and came inside with soldiers.")
    print('___________________________________________________________________________________________________________________\n\n')
    sleep(0.5)
    print("Arsanal" +A+" : Daniel I here by  arrest you under the highest authority.")
    sleep(0.5)
    print(" Daniel" +D+" : You may arrest me, but it is not by the highest authority")
    sleep(0.5)
    print("Arsanal" +A+" : You are coming with us")
    sleep(0.5)
    print("Arsanal" +A+" : Let it would be lesson to many who prays to God who is not King Darius.")
    print('___________________________________________________________________________________________________________________\n\n')
    sleep(0.5)
    print("  Joy" +J+" : Oh No")
    sleep(0.5)
    print("Chris" +C+" : It was almost like, he dont care that he will get thrown into the Lions for praying.")
    sleep(0.5)
    print("  Joy" +J+" : Daniel believed that what he was done was right Chris, regardless of consequences. And its the time we do the same\n\n")
    sleep(0.5)
    court()


# court - level 4
def court():
    C = u"\U0001F466\U0001F3FB"#emoji's
    J=u"\U0001F467\U0001F3FB"#emoji's
    G=u"\U0001F916"#emoji's
    K=u"\U0001F934\U0001F3FC"#emoji's
    M=u"\U0001F474\U0001F3FB"#emoji's
    T=u"\U0001F476\U0001F3FB"#emoji's
    B=u"\U0001F468\U0001F3FC\u200D\U0001F9B1"#emoji's
    A=u"\U0001F9DB\u200D\u2642\uFE0F"#emoji's
    D=u"\U0001F473\U0001F3FB"#emoji's
    SB=u"\U0001F4D5"#emoji's
    C1="\xee\x94\x9e"#emoji's
    C2=u"\U0001F482\U0001F3FE"#emoji's
    HE=u"\U0001F60D"#emoji's
    SF=u"\uE414"#emoji's
    SG=u"\U0001F576"#emoji's
    skateboard=u"\U0001F3C2"#emoji's
    sboard=	u"\U0001F6F9"#emoji's
    hahaha=	u"\U0001F602"#emoji's
    sad=u"\U0001F61E"#emoji's
    party=u"\U0001F973"#emoji's
    threepeople=u"\U0001F468\u200D\U0001F468\u200D\U0001F466"#emoji's
    trumpet=u"\U0001F3BA"#emoji's
    pray=u"\U0001F647\u200D\u2640\uFE0F"#emoji's
    exc=u"\u2668\uFE0F"#emoji's
    
    sleep(0.5)
    print('___________________________________________________________________________________________________________________\n\n')
    print(exc+"   Daniel is presented in the court")
    print('___________________________________________________________________________________________________________________\n\n')
    sleep(0.5)
    print("   King" +K+" : <<out of anger>> What is the meaning of this outrage")
    sleep(0.5)
    print("Arnasal" +A+" : We caught Daniel praying to his God... and not to you.")
    sleep(0.5)
    print("   King" +K+" : Daniel....")
    sleep(0.5)
    print("Arnasal" +A+" : The preparation for execution is ordered my Lord")
    sleep(0.5)
    print("   King" +K+" : Daniel is my friend")
    sleep(0.5)
    print("Arnasal" +A+" : A decree set forth by the king, after all,, is the law. It cannot be undone.")
    sleep(0.5)
    print("   King" +K+" :"+sad+" There must be a way")
    sleep(0.5)
    print("Arnasal" +A+" : My Lord It was your doing. It is done is done.")
    sleep(0.5)
    print("Arnasal" +A+" : If you swift with the first offender - you will appear weak and the kingdom will not give you due respect")
    sleep(0.5)
    print(" Daniel" +D+" : I respect you with all my heart King. But I will not respect any decree that stopping me to pray to one true God.")
    sleep(0.5)
    print("   King" +K+" : your God means this much to you?")
    sleep(0.5)
    print(" Daniel" +D+" : He does")
    sleep(0.5)
    
    #propting the user to input the desired 
    gaint2 = input(prompt = f"Do you want to tell King about this Trap?\nIf yes press y")
    gaint2 = gaint2.casefold()
    loop4=0
    #using the while loop to repeat untill the user selects the required options 
    while loop4==0:
        #conditions to give the options to user
        if gaint2 == 'y':
            loop4 += 1
            king_room()
            break
        
        elif gaint2 == 'n':
            fail()
            exit()
            break
            

        else:
            print('Invalid entry\n')
            gaint2 = input(prompt = "Do you want to tell king about this trap?\nIf yes press y")
            gaint2 = gaint2.casefold()
            continue
    

    
#King's room
def king_room():
    C = u"\U0001F466\U0001F3FB"#emoji's
    J=u"\U0001F467\U0001F3FB"#emoji's
    G=u"\U0001F916"#emoji's
    K=u"\U0001F934\U0001F3FC"#emoji's
    M=u"\U0001F474\U0001F3FB"#emoji's
    T=u"\U0001F476\U0001F3FB"#emoji's
    B=u"\U0001F468\U0001F3FC\u200D\U0001F9B1"#emoji's
    A=u"\U0001F9DB\u200D\u2642\uFE0F"#emoji's
    D=u"\U0001F473\U0001F3FB"#emoji's
    SB=u"\U0001F4D5"#emoji's
    C1="\xee\x94\x9e"#emoji's
    C2=u"\U0001F482\U0001F3FE"#emoji's
    HE=u"\U0001F60D"#emoji's
    SF=u"\uE414"#emoji's
    SG=u"\U0001F576"#emoji's
    skateboard=u"\U0001F3C2"#emoji's
    sboard=	u"\U0001F6F9"#emoji's
    hahaha=	u"\U0001F602"#emoji's
    sad=u"\U0001F61E"#emoji's
    party=u"\U0001F973"#emoji's
    threepeople=u"\U0001F468\u200D\U0001F468\u200D\U0001F466"#emoji's
    trumpet=u"\U0001F3BA"#emoji's
    pray=u"\U0001F647\u200D\u2640\uFE0F"#emoji's
    exc=u"\u2668\uFE0F"#emoji's
    
    #printing the required outputs
    sleep(0.5)
    print("Congratulation!"+party+" You are promoted to level 3\n\n")
    sleep(0.5)
    print("Joy came to meet King"+J+ K)
    print('___________________________________________________________________________________________________________________\n\n')
    sleep(0.5)
    print("King" +K+" : Who approaches?")
    sleep(0.5)
    print(" Joy" +J+" : I am friend of Daniel. May I speak with you Lord?")
    sleep(0.5)
    print("King" +K+" : You risk your life to speak to me? What could possibly so important?")
    sleep(0.5)
    print(" Joy" +J+" : Doing the right Thing")
    sleep(0.5)
    print("King" +K+" : Pardon me?")
    sleep(0.5)
    print(" Joy" +J+" : Your Highness do you know that the men who asked you to enforce the decree are evil?")
    sleep(0.5)
    print("King" +K+" : I know they conspire for power. Sometime even the king is uncertain about what is right.")
    sleep(0.5)
    print("King" +K+" : <<Sadly>> I will not sleep this night")
    print('___________________________________________________________________________________________________________________\n\n')
    sleep(0.5)
    print("King didnot sleep whole night staring at the Lion's den")
    sleep(0.5)
    print("Joy, Giz and Chris praying to the Lord")
    print('___________________________________________________________________________________________________________________\n\n')
    sleep(0.5)
    print("The next day - King coming to Lion's den")
    sleep(0.5)
    #asking the user to select the required output
    gaint3 = input(prompt=f"Do you want to see Daniel?\nIf yes press y")
    gaint3 = gaint3.casefold()
    loop5=0
    #using loop to continue in th loop untill the user select the required options
    while loop5==0:
        #conditions for users
        if gaint3 == 'y':
            loop5 += 1
            lion_den()
            break
        
        elif gaint3 == 'n':
            fail()
            exit()
            break
            
        else:
            print('Invalid entry\n')
            gaint3 = input(prompt=f"Do you want to see daniel?\nIf yes press y")
            gaint3 = gaint3.casefold()
            continue
    
#Lion's den

def lion_den():
    
    C = u"\U0001F466\U0001F3FB"#emoji's
    J=u"\U0001F467\U0001F3FB"#emoji's
    G=u"\U0001F916"#emoji's
    K=u"\U0001F934\U0001F3FC"#emoji's
    M=u"\U0001F474\U0001F3FB"#emoji's
    T=u"\U0001F476\U0001F3FB"#emoji's
    B=u"\U0001F468\U0001F3FC\u200D\U0001F9B1"#emoji's
    A=u"\U0001F9DB\u200D\u2642\uFE0F"#emoji's
    D=u"\U0001F473\U0001F3FB"#emoji's
    SB=u"\U0001F4D5"#emoji's
    C1="\xee\x94\x9e"#emoji's
    C2=u"\U0001F482\U0001F3FE"#emoji's
    HE=u"\U0001F60D"#emoji's
    SF=u"\uE414"#emoji's
    SG=u"\U0001F576"#emoji's
    skateboard=u"\U0001F3C2"#emoji's
    sboard=	u"\U0001F6F9"#emoji's
    hahaha=	u"\U0001F602"#emoji's
    sad=u"\U0001F61E"#emoji's
    party=u"\U0001F973"#emoji's
    threepeople=u"\U0001F468\u200D\U0001F468\u200D\U0001F466"#emoji's
    trumpet=u"\U0001F3BA"#emoji's
    pray=u"\U0001F647\u200D\u2640\uFE0F"#emoji's
    exc=u"\u2668\uFE0F"#emoji's
    #printing the required print statements
    sleep(0.5)
    print("Arnasal" +A+" : Why do you hurry here My lord. Daniel certainly be died")
    sleep(0.5)
    print("   King" +K+" : we will find out whether Daniel's God is real")
    sleep(0.5)
    print("   King" +K+" : Soldiers move the stone.")
    sleep(0.5)
    print("   King" +K+" : <looking into the cave> Daniel, Daniel")
    sleep(0.5)
    print("Arnasal" +A+" : King! you are talking to the dead.")
    sleep(0.5)
    print("   King" +K+" : Daniel! You are faithful and served your God. Was he able to save you from the Lions.")
    sleep(0.5)
    print('___________________________________________________________________________________________________________________\n\n')
    print("silence, silence")
    print('___________________________________________________________________________________________________________________\n\n')
    sleep(0.5)
    print(" Daniel" +D+" : Long live The king!")
    sleep(0.5)
    print("Arnasal" +A+" : What? Impossible.")
    sleep(0.5)
    print("King,Joy,Giz,Chris: WOOOOhooo! He did it. He is alive. He made it.")
    sleep(0.5)
    print(" Daniel" +D+" : My God send his angel to shut the mouth of Lions,they would not hurt me for I have found innocent in his sight and King I have done no wrong to you")
    sleep(0.5)
    print("  King"  +K+" : Lift him out, I command everone in my kingdome to worship the God of Daniel.")
    sleep(0.5)
    print("Arnasal" +A+" : But why my lord?")
    sleep(0.5)
    print("   King" +K+" : He is living God and one who lives forever. His power and wisdom will never end.\n He rescues his people and set them free by doing great miracle.")
    sleep(0.5)
    print("   King" +K+" : Arnasal: You and your people will discover how Lion's roar will be")
    print('___________________________________________________________________________________________________________________\n\n')
    print('___________________________________________________________________________________________________________________\n\n')
    sleep(0.5)
    print("Joy" +J+" : Chris, Gizmo - Superbook is taking us home.")
    sleep(0.5)
    #prompting the user to give the input
    home1 = input(prompt = f"Do you want to go to present and Help Tommy\nIf yes press y")
    home1 = home1.casefold()
    loop6=0
    #Using the loop statements to continue untill the options displayed are selected
    while loop6 == 0:
        #conditions for the user selections.
        if home1 == 'y':
            loop6 += 1
            #divert to help_tommy
            help_tommy()
            break
        elif home1 == 'n':
            #diverting to fail the user and exit.
            fail()
            exit()
            break
        else:
            #propmt the user to continue for invalid selection.
            print('Invalid entry\n')
            home1 = input(prompt = f"Do you want to go to present and Help Tommy\nIf yes press y")
            home1 = home1.casefold()
            continue

            
#with complete strenght - help Tommy
def help_tommy():
    
    C = u"\U0001F466\U0001F3FB"#emoji's
    J=u"\U0001F467\U0001F3FB"#emoji's
    G=u"\U0001F916"#emoji's
    K=u"\U0001F934\U0001F3FC"#emoji's
    M=u"\U0001F474\U0001F3FB"#emoji's
    T=u"\U0001F476\U0001F3FB"#emoji's
    B=u"\U0001F468\U0001F3FC\u200D\U0001F9B1"#emoji's
    A=u"\U0001F9DB\u200D\u2642\uFE0F"#emoji's
    D=u"\U0001F473\U0001F3FB"#emoji's
    SB=u"\U0001F4D5"#emoji's
    C1="\xee\x94\x9e"#emoji's
    C2=u"\U0001F482\U0001F3FE"#emoji's
    HE=u"\U0001F60D"#emoji's
    SF=u"\uE414"#emoji's
    SG=u"\U0001F576"#emoji's
    skateboard=u"\U0001F3C2"#emoji's
    sboard=	u"\U0001F6F9"#emoji's
    hahaha=	u"\U0001F602"#emoji's
    sad=u"\U0001F61E"#emoji's
    party=u"\U0001F973"#emoji's
    threepeople=u"\U0001F468\u200D\U0001F468\u200D\U0001F466"#emoji's
    trumpet=u"\U0001F3BA"#emoji's
    pray=u"\U0001F647\u200D\u2640\uFE0F"#emoji's
    exc=u"\u2668\uFE0F"#emoji's
    
    #printing the required print statements
    print("Congratulations!"+party+"You have completed Level 3.\n\n")
    print("|||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||||\n")
    print('___________________________________________________________________________________________________________________\n\n')
    print(exc+"     Joy, Gizmo, Chris are back to present"+"     "+exc)
    print('___________________________________________________________________________________________________________________\n\n')
    print('___________________________________________________________________________________________________________________\n\n')
    sleep(0.5)
    print("Barry" +B+" : comeon baby tommy! Take the skate!! Baby! Hahahah")
    sleep(0.5)
    print("Chris" +C+" : Right back where we left, If Daniel could do right thing so I Do the right thing")
    sleep(0.5)
    print("Barry" +B+" : Chris! What is your deal. Why are you here?")
    sleep(0.5)
    print("Chris" +C+" : Tommy is my deal. Give him back his skateboard. Give it back now.")
    sleep(0.5)
    print("Barry" +B+" : Says who?")
    sleep(0.5)
    print("Chris" +C+" : Says me")
    sleep(0.5)
    print("Barry" +B+" : And who else?")
    sleep(0.5)
    print("  Joy" +J+" : Me")
    sleep(0.5)
    print("BarrY" +B+" : You? hahahahah")
    sleep(0.5)
    print("Tommy" +T+" : Me as well")
    sleep(0.5)
    print("Everyone there chanted me, me, me, me, me, me, me")
    sleep(0.5)
    print("Barry" +B+" : <<afraid>> Hey I was just messing around. These kids cant take jokes.")
    sleep(0.5)
    print("Tommy" +T+" : I am happy that I got my skateboard back. Thank you Chris")
    sleep(0.5)
    print("woooohooooooooooo - You won"+party+party+party+HE)
    print('___________________________________________________________________________________________________________________\n\n')
    print('___________________________________________________________________________________________________________________\n\n')
    #diverting to win function.
    win()  

#win - user defined function   
def win():
    HE=u"\U0001F60D"#emoji's
    print("""
 _     _                             _           _  _  _                                     
| |   | |                           (_)         | || || |                                    
| |___| |___   _   _          _ _ _  _  ____    | || || |                                    
 \_____// _ \ | | | |        | | | || ||  _ \   |_||_||_|                                    
   ___ | |_| || |_| |        | | | || || | | |   _  _  _                                     
  (___) \___/  \____|         \____||_||_| |_|  |_||_||_|                                    
  ______                                               _               _                     
 / _____)                                  _          | |        _    (_)                    
| /       ___   ____    ____   ____  ____ | |_  _   _ | |  ____ | |_   _   ___   ____    ___ 
| |      / _ \ |  _ \  / _  | / ___)/ _  ||  _)| | | || | / _  ||  _) | | / _ \ |  _ \  /___)
| \_____| |_| || | | |( ( | || |   ( ( | || |__| |_| || |( ( | || |__ | || |_| || | | ||___ |
 \______)\___/ |_| |_| \_|| ||_|    \_||_| \___)\____||_| \_||_| \___)|_| \___/ |_| |_|(___/ 
                      (_____|                                                                
    """)
    
    print(HE+HE+HE+HE+HE+HE+HE+HE+HE+HE+HE+HE+HE+HE+HE+HE+HE+HE+HE+HE+HE+HE+HE+HE+HE+HE+HE+HE+HE+HE+HE+HE+HE+HE+HE+HE+HE+HE+HE+HE+HE+HE+HE+HE+HE+HE+HE+HE+HE+HE+HE+HE+HE+HE)
    print("You helped Chris to fight his gaint")
    
#exit - user defined function
def exit():
    print("""
 #####                                                                            
#    #   ###### ######      #   #  ####  #    #        ####   ####   ####  #    # 
#       #      #             # #  #    # #    #       #      #    # #    # ##   # 
 #####  #####  #####          #   #    # #    #        ####  #    # #    # # #  # 
      # #      #              #   #    # #    #            # #    # #    # #  # # 
 #    # #      #              #   #    # #    #       #    # #    # #    # #   ## 
 #####  ###### ######         #    ####   ####         ####   ####   ####  #    # 
    """)
    
#fail - user defined function
def fail():
    sad=u"\U0001F61E"
    print()
    print("""                                                                               
 ooooo  oooo                                 ooooo                               o8   
  888   88  oooooooo  ooo   oooo             888          ooooooo    oooooooo8 o888oo 
    888    888    888 888    888             888        888     888 888ooooooo  888   
    888    888    888 888    888             888      o 888     888         888 888   
   o888o    88ooo88    888o88  8o           o888ooooo88   88ooo88   88oooooo88  888o                                                                                                                                                                                                                                           
    """)
    
    
#Starting the game    
characters()
